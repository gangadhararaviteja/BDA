# %%
import pandas as pd
data=pd.read_csv('dataset.csv')
data.head()
# Out:
#                  Name Twitter_username    Account_start_time  \
# 0  A. Donald McEachin      RepMcEachin  2017-01-03T00:00:00Z
# 1    Aaron Michlewitz    RepMichlewitz  2010-06-27T00:00:00Z
# 2        Aaron Peskin      AaronPeskin  2010-11-13T00:00:00Z
# 3          Aaron Peña        AaronPena  2007-10-31T00:00:00Z
# 4        Aaron Schock      aaronschock  2009-03-12T00:00:00Z
#
#            Account_ID   Sex                Birthplace              Birthday  \
# 0  816181091673448448  male                   Germany  1961-10-10T00:00:00Z
# 1           160246973  male  United States of America  1978-01-01T00:00:00Z
# 2           215369273  male  United States of America  1964-06-17T00:00:00Z
# 3             9843332  male  United States of America  1959-06-08T00:00:00Z
# 4            23951197  male  United States of America  1981-05-28T00:00:00Z
#
#     Age Instagram_username   Political_party
# 0  59.0        repmceachin  Democratic Party
# 1  42.0                NaN  Democratic Party
# 2  56.0          apeskin52  Democratic Party
# 3  61.0                NaN  Republican Party
# 4  39.0        aaronschock  Republican Party

# %%
import pandas as pd
data=pd.read_csv('dataset.csv')
data.head()

df_dropped=data.drop('Birthplace',axis=1)
df_dropped.head()

data.groupby('Sex').agg({'Political_party':'count'})

data.iloc[:5,8]

desc=data["Name"].describe()
desc

df_row_dropped=data.drop(2,axis=0)
df_row_dropped.head()

data.columns
df_renamed=data.rename(columns={'Account_ID':'Id'})
df_renamed.head()

# %%
df_dropped=data.drop('Birthplace',axis=1)
df_dropped.head()
# Out:
#                  Name Twitter_username    Account_start_time  \
# 0  A. Donald McEachin      RepMcEachin  2017-01-03T00:00:00Z
# 1    Aaron Michlewitz    RepMichlewitz  2010-06-27T00:00:00Z
# 2        Aaron Peskin      AaronPeskin  2010-11-13T00:00:00Z
# 3          Aaron Peña        AaronPena  2007-10-31T00:00:00Z
# 4        Aaron Schock      aaronschock  2009-03-12T00:00:00Z
#
#            Account_ID   Sex              Birthday   Age Instagram_username  \
# 0  816181091673448448  male  1961-10-10T00:00:00Z  59.0        repmceachin
# 1           160246973  male  1978-01-01T00:00:00Z  42.0                NaN
# 2           215369273  male  1964-06-17T00:00:00Z  56.0          apeskin52
# 3             9843332  male  1959-06-08T00:00:00Z  61.0                NaN
# 4            23951197  male  1981-05-28T00:00:00Z  39.0        aaronschock
#
#     Political_party
# 0  Democratic Party
# 1  Democratic Party
# 2  Democratic Party
# 3  Republican Party
# 4  Republican Party

# %%
data.groupby('Sex').agg({'Political_party':'count'})
# Out:
#                     Political_party
# Sex
# female                          730
# male                           1779
# transgender female                4
# transgender male                  1
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Political_party'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_1, *['Political_party'], **{})
# chart

# %%
data.iloc[:5,8]
# Out:
# 0    repmceachin
# 1            NaN
# 2      apeskin52
# 3            NaN
# 4    aaronschock
# Name: Instagram_username, dtype: object

# %%
desc=data["Name"].describe()
desc
# Out:
# count           2514
# unique          1806
# top       Ben Carson
# freq              12
# Name: Name, dtype: object

# %%
df_row_dropped=data.drop(2,axis=0)
df_row_dropped.head()
# Out:
#                  Name Twitter_username    Account_start_time  \
# 0  A. Donald McEachin      RepMcEachin  2017-01-03T00:00:00Z
# 1    Aaron Michlewitz    RepMichlewitz  2010-06-27T00:00:00Z
# 3          Aaron Peña        AaronPena  2007-10-31T00:00:00Z
# 4        Aaron Schock      aaronschock  2009-03-12T00:00:00Z
# 5     Abby Finkenauer        Abby4Iowa  2013-03-12T00:00:00Z
#
#            Account_ID     Sex                Birthplace              Birthday  \
# 0  816181091673448448    male                   Germany  1961-10-10T00:00:00Z
# 1           160246973    male  United States of America  1978-01-01T00:00:00Z
# 3             9843332    male  United States of America  1959-06-08T00:00:00Z
# 4            23951197    male  United States of America  1981-05-28T00:00:00Z
# 5          1262017122  female  United States of America  1988-12-27T00:00:00Z
#
#     Age Instagram_username   Political_party
# 0  59.0        repmceachin  Democratic Party
# 1  42.0                NaN  Democratic Party
# 3  61.0                NaN  Republican Party
# 4  39.0        aaronschock  Republican Party
# 5  31.0          abby4iowa  Democratic Party

# %%
data.columns
df_renamed=data.rename(columns={'Account_ID':'Id'})
df_renamed.head()
# Out:
#                  Name Twitter_username    Account_start_time  \
# 0  A. Donald McEachin      RepMcEachin  2017-01-03T00:00:00Z
# 1    Aaron Michlewitz    RepMichlewitz  2010-06-27T00:00:00Z
# 2        Aaron Peskin      AaronPeskin  2010-11-13T00:00:00Z
# 3          Aaron Peña        AaronPena  2007-10-31T00:00:00Z
# 4        Aaron Schock      aaronschock  2009-03-12T00:00:00Z
#
#                    Id   Sex                Birthplace              Birthday  \
# 0  816181091673448448  male                   Germany  1961-10-10T00:00:00Z
# 1           160246973  male  United States of America  1978-01-01T00:00:00Z
# 2           215369273  male  United States of America  1964-06-17T00:00:00Z
# 3             9843332  male  United States of America  1959-06-08T00:00:00Z
# 4            23951197  male  United States of America  1981-05-28T00:00:00Z
#
#     Age Instagram_username   Political_party
# 0  59.0        repmceachin  Democratic Party
# 1  42.0                NaN  Democratic Party
# 2  56.0          apeskin52  Democratic Party
# 3  61.0                NaN  Republican Party
# 4  39.0        aaronschock  Republican Party
